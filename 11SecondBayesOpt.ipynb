# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import psi4

from rdkit import Chem
from rdkit.Chem import AllChem, Draw, Descriptors

# %%
import bayes_opt_dis as bod

# %%
smiles_df=pd.read_csv("ProcessedData/smiles_chfcl.csv",index_col=0)
display(smiles_df.head())
# Out:
#                            SMILES
# 0  [H]C(F)(F)C([H])([H])C(F)(F)Cl
# 1  [H]C(F)(Cl)C([H])([H])C(F)(F)F
# 2             [H]C(Cl)=C=C([H])Cl
# 3         [H]C([H])(F)C([H])(F)Cl
# 4   [H]C([H])(Cl)C(F)(F)C(F)(F)Cl

# %%
desc_list = Descriptors.descList

desc_values=[]
mol_list=[]
for i,row in smiles_df.iterrows():
    mol=Chem.MolFromSmiles(row["SMILES"])
    mol_list.append(mol)
    desc_value_row=[]
    for desc in desc_list:
        try:
            desc_value_row.append(desc[1](mol))
        except:
            # エラーが発生したものについてはnp.NaNを代入
            desc_value_row.append(np.NaN)
    desc_values.append(desc_value_row)

# %%
# 記述子関数の辞書を作る
desc_dict={}
desc_name=[]
for desc in desc_list:
    desc_dict[desc[0]]=desc[1] 
    desc_name.append(desc[0])
    
logp_list=[]
for mol in mol_list:
    logp_list.append(desc_dict["MolLogP"](mol))
logp_df=pd.DataFrame(logp_list,columns=["LogP"])

# %%
desc_df=pd.DataFrame(desc_values,columns=desc_name)
# 欠損値を確認
desc_df.isnull().sum().sum()
# Out:
# 3

# %%
# 欠損値のある列を削除
desc_df=desc_df.dropna(axis=1)
# 欠損値を確認
desc_df.isnull().sum().sum()
# Out:
# 0

# %%
# 標準偏差が0のものを除去
desc_df2=desc_df.loc[:,desc_df.std()>0]

# %%
# 結合
mol_df=pd.DataFrame(mol_list,columns=["mol"])
desc_df3=pd.concat([smiles_df,mol_df,desc_df2],axis=1)
desc_df3.head()
desc_df3.tail()
# Out:
#                                    SMILES  \
# 573  [H]C([H])(F)C([H])([H])C([H])([H])Cl
# 574          [H]C(F)(Cl)C(F)(F)C(F)(Cl)Cl
# 575             [H]C(=C(F)F)C([H])([H])Cl
# 576          [H]C(F)(Cl)C(F)(Cl)C(F)(F)Cl
# 577              [H]C([H])([H])C(F)(Cl)Cl
#
#                                                   mol  MaxEStateIndex  \
# 573  <rdkit.Chem.rdchem.Mol object at 0x7f6847a90800>       10.909028
# 574  <rdkit.Chem.rdchem.Mol object at 0x7f6847a90b70>       11.907407
# 575  <rdkit.Chem.rdchem.Mol object at 0x7f6847a90a80>       10.811806
# 576  <rdkit.Chem.rdchem.Mol object at 0x7f6847a90e90>       12.096451
# 577  <rdkit.Chem.rdchem.Mol object at 0x7f6847a97300>       11.218364
#
#      MinEStateIndex  MaxAbsEStateIndex  MinAbsEStateIndex       qed    MolWt  \
# 573       -0.288194          10.909028           0.288194  0.458170   96.532
# 574       -4.599537          11.907407           3.243056  0.493847  219.392
# 575       -1.717593          10.811806           0.108796  0.455403  112.506
# 576       -4.518133          12.096451           3.054012  0.493847  219.392
# 577       -2.055556          11.218364           1.051698  0.425902  116.950
#
#      HeavyAtomMolWt  ExactMolWt  ...  FractionCSP3  HeavyAtomCount  \
# 573          90.484   96.014206  ...      1.000000               5
# 574         218.384  217.907996  ...      1.000000              10
# 575         109.482  111.989134  ...      0.333333               6
# 576         218.384  217.907996  ...      1.000000              10
# 577         113.926  115.959584  ...      1.000000               5
#
#      NumHeteroatoms  NumRotatableBonds  MolLogP   MolMR  fr_alkyl_halide  \
# 573               2                  2   1.5848  21.312                2
# 574               7                  2   3.2570  31.241                7
# 575               3                  1   2.0056  21.019                1
# 576               7                  2   3.2570  31.241                7
# 577               3                  0   2.1072  21.219                3
#
#      fr_allylic_oxid  fr_halogen  fr_term_acetylene
# 573                0           2                  0
# 574                0           7                  0
# 575                1           3                  0
# 576                0           7                  0
# 577                0           3                  0
#
# [5 rows x 97 columns]

# %%
desc_array=desc_df3.iloc[:,2:]

# 標準化
desc_array=desc_array.apply(lambda x: (x-x.mean())/x.std(ddof=1), axis=0)
desc_array.std(axis=0,ddof=1)
# Out:
# MaxEStateIndex       1.0
# MinEStateIndex       1.0
# MaxAbsEStateIndex    1.0
# MinAbsEStateIndex    1.0
# qed                  1.0
#                     ...
# MolMR                1.0
# fr_alkyl_halide      1.0
# fr_allylic_oxid      1.0
# fr_halogen           1.0
# fr_term_acetylene    1.0
# Length: 95, dtype: float64

# %%
#主成分分析
from sklearn.decomposition import PCA
pca = PCA(n_components= 6)
pca.fit(desc_array)
features = pca.transform(desc_array)
print("PCA後の形:",features.shape)
print('----寄与率----')
print(pca.explained_variance_ratio_)
print('----累計寄与率----')
print(sum(pca.explained_variance_ratio_))
# Out:
# PCA後の形: (578, 6)
# ----寄与率----
# [0.38166336 0.1367142  0.06183531 0.0452691  0.03247552 0.02773757]
# ----累計寄与率----
# 0.6856950699827866

# %%
import matplotlib.pyplot as plt

# plot biplot with data
fig=plt.figure(figsize=(10,150))
ax=fig.add_subplot()
for i in range(len(desc_array.columns)):
    pc1_comp=pca.components_[0,i]
    pc2_comp=pca.components_[1,i]
    ax.plot([0,pc1_comp],[0,pc2_comp],color="k")
    ax.text(x=pc1_comp*1.01,y=pc2_comp*1.01,s=desc_array.columns[i])

biplot_scale=0.02
for i in range(200):
    pc1_comp=features[i,0]*biplot_scale
    pc2_comp=features[i,1]*biplot_scale
    ax.scatter(pc1_comp,pc2_comp,color="C0")
    ax.text(x=pc1_comp*1.01,y=pc2_comp*1.01,s=desc_array.index[i])
ax.set_aspect('equal', adjustable='box')
xylim=0.3
ax.set_xlim([-xylim,xylim])
ax.set_ylim([-xylim,xylim])
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")

plt.tight_layout()

# %%
PC_names=["PC{}".format(i+1) for i in range(6)]
ft_value_df=pd.DataFrame(features,columns=PC_names)
ft_df=pd.concat([smiles_df,mol_df,logp_df,ft_value_df],axis=1)
ft_df.head()
# Out:
#                            SMILES  \
# 0  [H]C(F)(F)C([H])([H])C(F)(F)Cl
# 1  [H]C(F)(Cl)C([H])([H])C(F)(F)F
# 2             [H]C(Cl)=C=C([H])Cl
# 3         [H]C([H])(F)C([H])(F)Cl
# 4   [H]C([H])(Cl)C(F)(F)C(F)(F)Cl
#
#                                                 mol    LogP       PC1  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x7f684fd953f0>  2.4732 -2.612576
# 1  <rdkit.Chem.rdchem.Mol object at 0x7f684fd95300>  2.4732 -2.773286
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f684fd95a30>  2.0903  9.183354
# 3  <rdkit.Chem.rdchem.Mol object at 0x7f684fd95f80>  1.4903  4.486766
# 4  <rdkit.Chem.rdchem.Mol object at 0x7f684fce7260>  2.6921 -5.928476
#
#         PC2       PC3       PC4       PC5       PC6
# 0  3.464664  1.485989  0.635806 -0.959405 -0.040452
# 1  3.797525  1.459615  0.370234 -0.931962 -0.061093
# 2 -3.980349 -4.008471  1.818579 -0.254975  2.295698
# 3  1.840215  2.878088 -1.740072  1.326290 -1.713092
# 4  2.381269  0.427637  1.495679 -0.252014  2.435406

# %%
ft_df.to_pickle("ProcessedData/MolLogPFeatures.pkl")

# %%
ft_df=pd.read_pickle("ProcessedData/MolLogPFeatures.pkl")
features=ft_df.iloc[:,3:].values

# %%
# logpについてベイズ最適化し、図示
def func(mol_no):
    return ft_df.iloc[mol_no,2]

np.random.seed(0)
bayes_opt_dis=bod.BayesianOptDiscrete(func,features)
bayes_opt_dis.initial_estimate()
bayes_opt_dis.minimumize_func(niter=10)
bayes_opt_dis.plot_result(calc_remain=True)
bayes_opt_dis.plot_trasition()

# %%
bayes_opt_dis2=bod.BayesianOptDiscrete(func,features)
bayes_opt_dis2.set_initial_estimate(
    bayes_opt_dis.train_target_no_list,
    bayes_opt_dis.train_y_list
)
bayes_opt_dis2.minimumize_func(niter=100)
bayes_opt_dis2.plot_result(calc_remain=True)
bayes_opt_dis2.plot_trasition()
